# %% [markdown]
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;数据科学引论 - Python之道 </h1>
#
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;第4课 使用Python做数据分析-作业I </h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align=center>获取数据</h2>

# %% [markdown]
# #### 我们先通过下面的连接下载csv文件

# %%
#linux !wget --output-document /resources/data/co2emissions_cleaned.csv https://ibm.box.com/shared/static/w0opv0njjt6vh5d3w1sool0r9wsnow96.csv
#windwos用户请自行下载https://ibm.box.com/shared/static/w0opv0njjt6vh5d3w1sool0r9wsnow96.csv，将其命名为co2emissions_cleaned.csv保存到resources/data/co2emissions_cleaned.csv

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align=center>使用pandas导入数据</h2>

# %% [markdown]
# #### 载入`pandas`库

# %%
### Your Code here:
import pandas as pd

# %% [markdown]
# #### `pd.read_csv` 从 `pd.read_csv`导入数据

# %%
### Your Code here:

data = pd.read_csv("../data/co2emissions_cleaned.csv")

# %% [markdown]
# #### 使用 `head`函数输出数据的前5行

# %%
### Your Code here:

data.head(5)
# Out:
#   Country Name Country Code      1960      1961      1962      1963      1964  \
# 0        Aruba          ABW       NaN       NaN       NaN       NaN       NaN
# 1      Andorra          AND       NaN       NaN       NaN       NaN       NaN
# 2  Afghanistan          AFG  0.046068  0.053615  0.073781  0.074251  0.086317
# 3       Angola          AGO  0.104357  0.084718  0.216025  0.206877  0.216174
# 4      Albania          ALB  1.258195  1.374186  1.439956  1.181681  1.111742
#
#        1965      1966      1967          ...                2004       2005  \
# 0       NaN       NaN       NaN          ...           24.510543  24.964531
# 1       NaN       NaN       NaN          ...            7.208829   7.088128
# 2  0.101499  0.107674  0.123782          ...            0.040727   0.054855
# 3  0.206089  0.265164  0.166659          ...            1.086605   1.069417
# 4  1.166099  1.333055  1.363746          ...            1.376213   1.412498
#
#         2006       2007       2008       2009       2010       2011  \
# 0  24.766706  25.613715  24.750133  24.876706  24.182702  23.922412
# 1   6.553477   6.350868   6.296125   6.049173   6.124770   5.968685
# 2   0.065816   0.088141   0.158962   0.249074   0.302936   0.425262
# 3   1.200877   1.311096   1.369425   1.430873   1.401654   1.354008
# 4   1.291548   1.507536   1.580113   1.533178   1.515632   1.607038
#
#                       Region           IncomeGroup
# 0  Latin America & Caribbean  High income: nonOECD
# 1      Europe & Central Asia  High income: nonOECD
# 2                 South Asia            Low income
# 3         Sub-Saharan Africa   Upper middle income
# 4      Europe & Central Asia   Upper middle income
#
# [5 rows x 56 columns]

# %% [markdown]
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# <h1, align=center>数据挖掘</h1>

# %% [markdown]
# ## 2011年哪个国家的人均二氧化碳排放量（CO2 emissions per capita）最高？

# %%
### Your Code here:
data.sort_values('2011')[:1]['Country Name']
# Out:
# 12    Burundi
# Name: Country Name, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ## 2011年哪个国家的人均二氧化碳排放量（CO2 emissions per capita）最低?

# %%
## YOUR CODE BELOW
### Your Code here:
data.sort_values('2011')[-1:]['Country Name']
# Out:
#                  Country Name Country Code       1960       1961       1962  \
# 12                    Burundi          BDI        NaN        NaN   0.015203
# 172                      Chad          TCD   0.018319   0.016769   0.027012
# 196          Congo, Dem. Rep.          COD   0.152228   0.150782   0.135559
# 161                   Somalia          SOM   0.030598   0.031267   0.036990
# 153                    Rwanda          RWA   0.036252   0.046509   0.027647
# 30   Central African Republic          CAF   0.058535   0.057551   0.047114
# 127                    Malawi          MWI        NaN        NaN        NaN
# 119                      Mali          MLI   0.022990   0.022048   0.025894
# 57                   Ethiopia          ETH   0.015892   0.015043   0.017055
# 131                     Niger          NER   0.008640   0.015744   0.018352
# 54                    Eritrea          ERI        NaN        NaN        NaN
# 183                    Uganda          UGA   0.062123   0.058093   0.059258
# 114                Madagascar          MDG   0.078383   0.068094   0.073988
# 15               Burkina Faso          BFA   0.009112   0.018730   0.017003
# 124                Mozambique          MOZ   0.251537   0.344473   0.254829
# 69              Guinea-Bissau          GNB   0.029745   0.047057   0.064030
# 159              Sierra Leone          SLE   0.327756   0.131073   0.145725
# 182                  Tanzania          TZA   0.082261   0.067872   0.071734
# 136                     Nepal          NPL   0.008022   0.007897   0.008481
# 177               Timor-Leste          TLS        NaN        NaN        NaN
# 100                   Lao PDR          LAO   0.038055   0.052403   0.059466
# 121                   Myanmar          MMR   0.126463   0.118050   0.128405
# 197                    Zambia          ZMB        NaN        NaN        NaN
# 79                      Haiti          HTI   0.073982   0.075323   0.075663
# 102                   Liberia          LBR   0.147294   0.140928   0.216210
# 39                    Comoros          COM   0.058289   0.057348   0.056427
# 67                     Guinea          GIN   0.114805   0.169536   0.178832
# 68                Gambia, The          GMB   0.049833   0.058402   0.066929
# 36                   Cameroon          CMR   0.050614   0.051577   0.051789
# 95                   Cambodia          KHM   0.041012   0.048708   0.051111
# ..                        ...          ...        ...        ...        ...
# 87                     Israel          ISR   3.059852   3.235687   3.463900
# 135                    Norway          NOR   3.658564   3.698694   3.868626
# 195              South Africa          ZAF   5.629718   5.694383   5.729712
# 91                      Japan          JPN   2.516538   2.981979   3.059736
# 134               Netherlands          NLD   6.399180   6.520358   7.060854
# 58                    Finland          FIN   3.409847   3.348877   3.742567
# 43             Cayman Islands          CYM   1.398373   1.370670   1.351142
# 45             Czech Republic          CZE        NaN        NaN        NaN
# 143                     Palau          PLW   1.521893   5.185133   5.057931
# 61             Faeroe Islands          FRO   1.712251   3.273164   3.338093
# 98                Korea, Rep.          KOR   0.501837   0.561315   0.651714
# 176              Turkmenistan          TKM        NaN        NaN        NaN
# 73                  Greenland          GRL   6.882677   8.705045   7.543543
# 152        Russian Federation          RUS        NaN        NaN        NaN
# 56                    Estonia          EST        NaN        NaN        NaN
# 31                     Canada          CAN  10.770847  10.627898  11.130627
# 130             New Caledonia          NCL  10.908165  10.928744   6.771199
# 92                 Kazakhstan          KAZ        NaN        NaN        NaN
# 9                   Australia          AUS   8.582937   8.641569   8.835688
# 186             United States          USA  15.999779  15.681256  16.013937
# 18                    Bahrain          BHR   3.542864  10.547396   9.193609
# 154              Saudi Arabia          SAU   0.655056   0.846589   1.433898
# 138                      Oman          OMN        NaN        NaN        NaN
# 5        United Arab Emirates          ARE   0.118786   0.108937   0.163355
# 95    0.285282   0.292181   0.291551   0.308073         East Asia & Pacific
# ..         ...        ...        ...        ...                         ...
# 87    9.340595   8.612963   9.036666   8.952414  Middle East & North Africa
# 135  10.554461  10.818606  11.616193   9.192879       Europe & Central Asia
# 195   9.506481   9.545495   8.957154   9.257216          Sub-Saharan Africa
# 91    9.422961   8.598622   9.127185   9.291834         East Asia & Pacific
# 134  10.529452  10.245619  10.949316  10.064490       Europe & Central Asia
# 58   10.651652   9.958629  11.530840  10.164046       Europe & Central Asia
# 43   11.224450  10.335286  10.173449  10.304931   Latin America & Caribbean
# 45   11.240129  10.305162  10.613368  10.431088       Europe & Central Asia
# 143  10.333663  10.274233  10.569272  10.855430         East Asia & Pacific
# 61   12.970121  11.842902  12.986678  11.721212       Europe & Central Asia
# 98   10.369833  10.346506  11.469587  11.840757         East Asia & Pacific
# 176  11.557572  10.110661  11.358111  12.183667       Europe & Central Asia
# 73   11.718151  10.221739  11.663773  12.440341       Europe & Central Asia
# 152  12.019131  11.026116  12.198437  12.647328       Europe & Central Asia
# 56   13.081834  11.048963  13.773197  14.049883       Europe & Central Asia
# 31   16.366165  15.089098  14.589054  14.135813               North America
# 130  13.531310  11.570830  15.680092  15.173295         East Asia & Pacific
# 92   14.659578  13.309728  15.146478  15.810098       Europe & Central Asia
# 9    17.704080  17.631833  16.710904  16.519210         East Asia & Pacific
# 186  18.489234  17.192379  17.484792  17.020216               North America
# 18   21.519995  18.136234  18.435025  17.947330  Middle East & North Africa
# 154  15.639313  17.690225  18.977626  18.072451  Middle East & North Africa
# 138  14.479797  13.926797  19.122607  20.203895  Middle East & North Africa
# 5    23.033600  21.102296  20.120957  20.433838  Middle East & North Africa
# 109  22.385472  20.877125  21.635136  20.897812       Europe & Central Asia
# 0    24.750133  24.876706  24.182702  23.922412   Latin America & Caribbean
# 27   26.338271  22.149029  21.873222  24.392013         East Asia & Pacific
# 99   30.581264  29.721704  29.693433  28.102662  Middle East & North Africa
# 179  35.455298  36.569448  38.337841  37.140054   Latin America & Caribbean
# 150  48.601620  44.836401  42.639076  44.018926  Middle East & North Africa
#
#               IncomeGroup
# 12             Low income
# 172            Low income
# 196            Low income
# 161            Low income
# 153            Low income
# 30             Low income
# 127            Low income
# 119            Low income
# 57             Low income
# 131            Low income
# 54             Low income
# 183            Low income
# 114            Low income
# 15             Low income
# 124            Low income
# 69             Low income
# 159            Low income
# 182            Low income
# 136            Low income
# 177   Lower middle income
# 100   Lower middle income
# 121   Lower middle income
# 197   Lower middle income
# 79             Low income
# 102            Low income
# 39             Low income
# 67             Low income
# 68             Low income
# 36    Lower middle income
# 95             Low income
# ..                    ...
# 87      High income: OECD
# 135     High income: OECD
# 195   Upper middle income
# 91      High income: OECD
# 134     High income: OECD
# 58      High income: OECD
# 43   High income: nonOECD
# 45      High income: OECD
# 143   Upper middle income
# 61   High income: nonOECD
# 98      High income: OECD
# 176   Upper middle income
# 73   High income: nonOECD
# 152  High income: nonOECD
# 56      High income: OECD
# 31      High income: OECD
# 130  High income: nonOECD
# 92    Upper middle income
# 9       High income: OECD
# 186     High income: OECD
# 18   High income: nonOECD
# 154  High income: nonOECD
# 138  High income: nonOECD
# 5    High income: nonOECD
# 109     High income: OECD
# 0    High income: nonOECD
# 27   High income: nonOECD
# 99   High income: nonOECD
# 179  High income: nonOECD
# 150  High income: nonOECD
#
# [199 rows x 56 columns]

# %% [markdown]
# <br>

# %% [markdown]
# ## 对于所有国家，每年人均二氧化碳的排放量在如何变化？

# %% [markdown]
# #### 绘制从1960年至2011的世界平均值图

# %% [markdown]
# 载入matplotlib模块用于绘制图形

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 生成图

# %%
#Assign x,y values
mydf = data
world_x = mydf[mydf.columns[2:54]].mean().index
world_y = mydf[mydf.columns[2:54]].mean()

#Plot
plt.plot(world_x, world_y)
plt.title("CO2 Emissions per capita averaged across all countries")
plt.ylabel("Mean CO2 Emissions (metric tons/capita)")
plt.xlabel("Year")

# %% [markdown]
# ## 2011年哪个地区的二氧化碳排放量（CO2 emissions）最高?

# %% [markdown]
# #### 一共有哪些地区?

# %%
mydf.Region
# Out:
# 0       Latin America & Caribbean
# 1           Europe & Central Asia
# 2                      South Asia
# 3              Sub-Saharan Africa
# 4           Europe & Central Asia
# 5      Middle East & North Africa
# 6       Latin America & Caribbean
# 7           Europe & Central Asia
# 8       Latin America & Caribbean
# 9             East Asia & Pacific
# 10          Europe & Central Asia
# 11          Europe & Central Asia
# 12             Sub-Saharan Africa
# 13          Europe & Central Asia
# 14             Sub-Saharan Africa
# 15             Sub-Saharan Africa
# 16                     South Asia
# 17          Europe & Central Asia
# 18     Middle East & North Africa
# 19      Latin America & Caribbean
# 20          Europe & Central Asia
# 21          Europe & Central Asia
# 22      Latin America & Caribbean
# 23                  North America
# 24      Latin America & Caribbean
# 25      Latin America & Caribbean
# 26      Latin America & Caribbean
# 27            East Asia & Pacific
# 28                     South Asia
# 29             Sub-Saharan Africa
#                   ...
# 169            Sub-Saharan Africa
# 170    Middle East & North Africa
# 171     Latin America & Caribbean
# 172            Sub-Saharan Africa
# 173            Sub-Saharan Africa
# 174           East Asia & Pacific
# 175         Europe & Central Asia
# 176         Europe & Central Asia
# 177           East Asia & Pacific
# 178           East Asia & Pacific
# 179     Latin America & Caribbean
# 180    Middle East & North Africa
# 181         Europe & Central Asia
# 182            Sub-Saharan Africa
# 183            Sub-Saharan Africa
# 184         Europe & Central Asia
# 185     Latin America & Caribbean
# 186                 North America
# 187         Europe & Central Asia
# 188     Latin America & Caribbean
# 189     Latin America & Caribbean
# 190           East Asia & Pacific
# 191           East Asia & Pacific
# 192    Middle East & North Africa
# 193           East Asia & Pacific
# 194    Middle East & North Africa
# 195            Sub-Saharan Africa
# 196            Sub-Saharan Africa
# 197            Sub-Saharan Africa
# 198            Sub-Saharan Africa
# Name: Region, dtype: object

# %% [markdown]
# #### 返回唯一的地区（去掉重名地区）:

# %%
mydf.Region.unique()
# Out:
# array(['Latin America & Caribbean', 'Europe & Central Asia', 'South Asia',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %% [markdown]
# #### 根据地区分组，然后使用mean函数做聚合

# %%
by_region = mydf.groupby('Region').agg('mean') #groupby then aggregate
by_region['2011']
# Out:
# Region
# East Asia & Pacific            4.835016
# Europe & Central Asia          6.790888
# Latin America & Caribbean      4.555243
# Middle East & North Africa     9.767944
# North America                 12.411080
# South Asia                     1.039568
# Sub-Saharan Africa             0.981220
# Name: 2011, dtype: float64

# %% [markdown]
# #### 获得聚合后的结果

# %%
by_region['2011']
# Out:
# Region
# East Asia & Pacific            4.835016
# Europe & Central Asia          6.790888
# Latin America & Caribbean      4.555243
# Middle East & North Africa     9.767944
# North America                 12.411080
# South Asia                     1.039568
# Sub-Saharan Africa             0.981220
# Name: 2011, dtype: float64

# %% [markdown]
# #### 绘制2011年地区平均二氧化碳排放量图

# %%
plt.bar(range(len(by_region['2011'])),by_region['2011'].values)
plt.xticks(range(len(by_region['2011'])), by_region['2011'].index, rotation=70)
plt.ylabel('CO2 Emission (metric ton/capita)')
plt.title('Mean CO2 Emission by Region in 2011')

# %% [markdown]
# <br>

# %% [markdown]
# ### <span style="color: red">轮到你了:</span>
# ## 2011年哪个收入群体有最高的平均二氧化碳排放量?

# %% [markdown]
# 第一，先在mydf中得到收入群体种类，注意使用**unique**去除重复。

# %%
## MY CODE BELOW
mydf.IncomeGroup.unique()

# %% [markdown]
# 然后，对数据帧进行分组，通过IncomeGroup这一列进行分组，然后聚合求平均

# %%
## MY CODE BELOW

# Remember to limit to 2011. 
# Assign result to a new variable, by_incomegroup

by_IncomeGroup = mydf.groupby('IncomeGroup').agg('mean')

# %% [markdown]
# 在条线图(bar graph)中绘制结果

# %%
## MY CODE BELOW

plt.bar(range(len(by_IncomeGroup['2011'])), by_IncomeGroup['2011'].values)
plt.xticks(range(len(by_IncomeGroup['2011'])), by_IncomeGroup['2011'].index, rotation=70)
plt.ylabel('CO2 Emission (metric ton/capita)')
plt.title('Mean CO2 Eromission by IncomeGroup in 2011')

# %% [markdown]
# <br><hr>

# %% [markdown]
# ## 展示1960年至2011年的二氧化碳排放量趋势

# %% [markdown]
# 我们可以创建一个折线图来展示这个趋势

# %%
def plot_countries(mydf):
    from pylab import rcParams
    rcParams['figure.figsize'] = (12,6)
    import numpy as np

    colormap = plt.cm.gist_ncar
    plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, len(range(1960,2012)))])


    for i in range(0,len(mydf)):
        plt.plot(mydf.iloc[i,][2:54])
    plt.xticks(range(len(range(1960,2012))),mydf.columns.values[2:54], rotation = 70)
    #plt.legend(mydf["Country Name"].values, loc='upper left')
    plt.legend(mydf["Country Name"].values, ncol=4, loc='upper center', 
               bbox_to_anchor=[0.4, -0.1], 
               columnspacing=1.0, labelspacing=0.0,
               handletextpad=0.0, handlelength=1.0,
               fancybox=True)
    plt.ylabel("CO2 Emission (metric ton/capita)")
    plt.title("CO2 Emission Per Capita by Country and Year")
    plt.show()

# %%
plot_countries(mydf)
# Out:
# /home/irving/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# <hr>
