# %% [markdown]
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;数据科学引论 - Python之道 </h1>
#
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;第4课 数据清洗 </h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <h1, align="center">按国家和年份统计的CO2排放量</h1>

# %% [markdown]
# 二氧化碳排放源自燃烧化石燃料和水泥制造，包含了在固体、液体和气体燃料消耗以及放空燃烧过程中所产生的二氧化碳

# %% [markdown]
# http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/

# %% [markdown]
# <h2, align=center>获取数据</h2>

# %% [markdown]
# 这些数据可以从世界银行(World Bank) [链接](http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/) 或者从 Box [链接](https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv) 上下载

# %% [markdown]
# #### 我们在linux下可以使用bash命令 `wget` 从链接处获取 csv 文件

# %%
# !wget --output-document /resources/data/co2emissions.csv https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align=center>使用 Pandas 导入数据</h2>

# %% [markdown]
# #### 导入所需的 `pandas` 库

# %%
import pandas as pd

# %% [markdown]
# #### 使用 `pd.read_csv` 导入数据

# %%
data = pd.read_csv("./data/co2emissions.csv", skiprows = 4)

# %% [markdown]
# #### 使用 `head` 显示 `data`  的前5行

# %%
data
# Out:
#                        Country Name Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# ..                              ...          ...
# 219                        Thailand          THA
# 220                      Tajikistan          TJK
# 221                    Turkmenistan          TKM
# 222                     Timor-Leste          TLS
# 223                           Tonga          TON
# 224             Trinidad and Tobago          TTO
# 225                         Tunisia          TUN
# 226                          Turkey          TUR
# 227                          Tuvalu          TUV
# 228                   Taiwan, China          TWN
# 229                        Tanzania          TZA
# 230                          Uganda          UGA
# 231                         Ukraine          UKR
# 232             Upper middle income          UMC
# 233                         Uruguay          URY
# 234                   United States          USA
# 235                      Uzbekistan          UZB
# 236  St. Vincent and the Grenadines          VCT
# 237                   Venezuela, RB          VEN
# 238           Virgin Islands (U.S.)          VIR
# 239                         Vietnam          VNM
# 240                         Vanuatu          VUT
# 241              West Bank and Gaza          PSE
# 242                           World          WLD
# 243                           Samoa          WSM
# 244                     Yemen, Rep.          YEM
# 245                    South Africa          ZAF
# 246                Congo, Dem. Rep.          COD
# 247                          Zambia          ZMB
# 248                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643964
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# ..                                      ...             ...        ...
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 231  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.288256
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.096144
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 248  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965     ...       \
# 0          NaN        NaN        NaN        NaN        NaN     ...
# 1          NaN        NaN        NaN        NaN        NaN     ...
# 2     0.053615   0.073781   0.074251   0.086317   0.101499     ...
# 3     0.084718   0.216025   0.206877   0.216174   0.206089     ...
# 4     1.374186   1.439956   1.181681   1.111742   1.166099     ...
# 5     0.685501   0.761148   0.875124   0.999248   1.166075     ...
# 6     0.108937   0.163355   0.175712   0.132651   0.146370     ...
# 7     2.442616   2.522392   2.316356   2.538380   2.641714     ...
# 8          NaN        NaN        NaN        NaN        NaN     ...
# 9          NaN        NaN        NaN        NaN        NaN     ...
# 10    0.860441   1.823374   1.470175   1.567094   2.520359     ...
# 11    8.641569   8.835688   9.226440   9.759073  10.622321     ...
# 12    4.496362   4.755362   5.155194   5.391004   5.252197     ...
# 13         NaN        NaN        NaN        NaN        NaN     ...
# 14         NaN   0.015203   0.016155   0.015827   0.011910     ...
# 15   10.103872  10.641190  11.386929  11.053655  11.141656     ...
# 16    0.052046   0.054202   0.047580   0.055295   0.057115     ...
# 17    0.018730   0.017003   0.017504   0.021575   0.019841     ...
# 18         NaN        NaN        NaN        NaN        NaN     ...
# 19    3.269920   3.835892   4.259781   5.262988   5.645652     ...
# 20   10.547396   9.193609   6.714156   8.747480   6.557022     ...
# 21    4.746699   5.996432   5.558199   8.118597   9.399946     ...
# 22         NaN        NaN        NaN        NaN        NaN     ...
# 23         NaN        NaN        NaN        NaN        NaN     ...
# 24    0.387219   0.715409   0.622357   0.818289   0.794763     ...
# 25    3.868484   3.383712   3.151929   4.124438   3.586487     ...
# 26    0.276621   0.286626   0.310159   0.371216   0.371151     ...
# 27    0.658625   0.697281   0.700749   0.694001   0.670372     ...
# 28    0.838899   1.119411   0.816330   0.766085   0.872454     ...
# 29    3.552009   4.133422   3.798174   3.482289   3.254787     ...
# ..         ...        ...        ...        ...        ...     ...
# 219   0.146944   0.173130   0.185877   0.242240   0.234151     ...
# 220        NaN        NaN        NaN        NaN        NaN     ...
# 221        NaN        NaN        NaN        NaN        NaN     ...
# 222        NaN        NaN        NaN        NaN        NaN     ...
# 223   0.172592   0.166040   0.159435   0.153309   0.147936     ...
# 224   5.318141   8.225570   1.466683   4.201774   5.694904     ...
# 225   0.413220   0.412987   0.438885   0.608626   0.532230     ...
# 226   0.615079   0.748241   0.765934   0.869390   0.883506     ...
# 227        NaN        NaN        NaN        NaN        NaN     ...
# 228        NaN        NaN        NaN        NaN        NaN     ...
# 229   0.067872   0.071734   0.072968   0.091197   0.099494     ...
# 230   0.058093   0.059258   0.057791   0.063435   0.078242     ...
# 231        NaN        NaN        NaN        NaN        NaN     ...
# 232   1.057435   0.957318   0.955719   0.982914   1.036033     ...
# 233   1.602723   1.540657   1.639285   1.710101   2.049519     ...
# 234  15.681256  16.013937  16.482762  16.968119  17.451725     ...
# 235        NaN        NaN        NaN        NaN        NaN     ...
# 236   0.133923   0.132214   0.174273   0.215513   0.170614     ...
# 237   6.136886   6.155057   6.155748   5.973226   6.187252     ...
# 238        NaN        NaN        NaN        NaN        NaN     ...
# 239   0.225435   0.258760   0.247579   0.314058   0.343354     ...
# 240        NaN   0.594888   0.471728   0.864247   0.641714     ...
# 241        NaN        NaN        NaN        NaN        NaN     ...
# 242   3.067062   3.138020   3.242364   3.358696   3.437595     ...
# 243   0.163529   0.158352   0.184019   0.208092   0.230869     ...
# 244   0.507631   0.728004   0.537606   0.658012   0.699574     ...
# 245   5.694383   5.729712   5.799844   6.170936   6.467359     ...
# 246   0.150782   0.135559   0.139446   0.116926   0.142290     ...
# 247        NaN        NaN        NaN   0.950434   1.100197     ...
# 248        NaN        NaN        NaN   1.045374   1.179176     ...
#
#           2007       2008       2009       2010       2011  2012  2013  2014  \
# 0    25.613715  24.750133  24.876706  24.182702  23.922412   NaN   NaN   Na
NaN        NaN        NaN        NaN        NaN   NaN   NaN   NaN
# 228        NaN        NaN        NaN        NaN        NaN   NaN   NaN   NaN
# 229   0.144041   0.147982   0.139973   0.150059   0.154935   NaN   NaN   NaN
# 230   0.104293   0.101919   0.105320   0.108297   0.110887   NaN   NaN   NaN
# 231   6.910708   6.724046   5.647014   6.638152   6.262352   NaN   NaN   NaN
# 232   4.689606   4.838241   5.074839   5.359268   5.710659   NaN   NaN   NaN
# 233   1.796306   2.471054   2.401221   1.912605   2.296201   NaN   NaN   NaN
# 234  19.237460  18.489234  17.192379  17.484792  17.020216   NaN   NaN   NaN
# 235   4.391447   4.434466   3.912053   3.693268   3.914921   NaN   NaN   NaN
# 236   2.084879   2.116255   2.114512   2.146877   2.179923   NaN   NaN   NaN
# 237   5.868518   6.604892   6.525293   6.811756   6.416334   NaN   NaN   NaN
# 238        NaN        NaN        NaN        NaN        NaN   NaN   NaN   NaN
# 239   1.352791   1.497496   1.636371   1.761695   1.971889   NaN   NaN   NaN
# 240   0.433459   0.406839   0.508463   0.496591   0.591266   NaN   NaN   NaN
# 241   0.665297   0.570947   0.564578   0.534015   0.572407   NaN   NaN   NaN
# 242   4.686122   4.741826   4.663120   4.840436   4.944676   NaN   NaN   NaN
# 243   1.026224   1.039490   1.072106   1.103871   1.252110   NaN   NaN   NaN
# 244   0.981422   0.989905   1.026251   1.090060   0.919968   NaN   NaN   NaN
# 245   9.063326   9.506481   9.545495   8.957154   9.257216   NaN   NaN   NaN
# 246   0.047312   0.048411   0.045604   0.049328   0.050303   NaN   NaN   NaN
# 247   0.150265   0.164692   0.184058   0.192079   0.212450   NaN   NaN   NaN
# 248   0.731867   0.569255   0.600521   0.646073   0.691698   NaN   NaN   NaN
#
#      2015  Unnamed: 60
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN
# 5     NaN          NaN
# 6     NaN          NaN
# 7     NaN          NaN
# 8     NaN          NaN
# 9     NaN          NaN
# 10    NaN          NaN
# 11    NaN          NaN
# 12    NaN          NaN
# 13    NaN          NaN
# 14    NaN          NaN
# 15    NaN          NaN
# 16    NaN          NaN
# 17    NaN          NaN
# 18    NaN          NaN
# 19    NaN          NaN
# 20    NaN          NaN
# 21    NaN          NaN
# 22    NaN          NaN
# 23    NaN          NaN
# 24    NaN          NaN
# 25    NaN          NaN
# 26    NaN          NaN
# 27    NaN          NaN
# 28    NaN          NaN
# 29    NaN          NaN
# ..    ...          ...
# 219   NaN          NaN
# 220   NaN          NaN
# 221   NaN          NaN
# 222   NaN          NaN
# 223   NaN          NaN
# 224   NaN          NaN
# 225   NaN          NaN
# 226   NaN          NaN
# 227   NaN          NaN
# 228   NaN          NaN
# 229   NaN          NaN
# 230   NaN          NaN
# 231   NaN          NaN
# 232   NaN          NaN
# 233   NaN          NaN
# 234   NaN          NaN
# 235   NaN          NaN
# 236   NaN          NaN
# 237   NaN          NaN
# 238   NaN          NaN
# 239   NaN          NaN
# 240   NaN          NaN
# 241   NaN          NaN
# 242   NaN          NaN
# 243   NaN          NaN
# 244   NaN          NaN
# 245   NaN          NaN
# 246   NaN          NaN
# 247   NaN          NaN
# 248   NaN          NaN
#
# [249 rows x 61 columns]

# %% [markdown]
# <h1, align=center>数据清洗</h1>

# %% [markdown]
# #### 观察这些数据，其质量有什么问题？我们应该如何解决这些问题？

# %% [markdown]
# 例如，下面这些行有什么问题？

# %%
data.loc[[9,190,220,257]]
# Out:
#            Country Name Country Code                          Indicator Name  \
# 9        American Samoa          ASM  CO2 emissions (metric tons per capita)
# 190  Russian Federation          RUS  CO2 emissions (metric tons per capita)
# 220          Tajikistan          TJK  CO2 emissions (metric tons per capita)
# 257                 NaN          NaN                                     NaN
#
#      Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 9    EN.ATM.CO2E.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 190  EN.ATM.CO2E.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 220  EN.ATM.CO2E.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 257             NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#           2007       2008       2009       2010       2011  2012  2013  2014  \
# 9          NaN        NaN        NaN        NaN        NaN   NaN   NaN   NaN
# 190  11.677438  12.019131  11.026116  12.198437  12.647328   NaN   NaN   NaN
# 220   0.463345   0.409462   0.382775   0.373873   0.358948   NaN   NaN   NaN
# 257        NaN        NaN        NaN        NaN        NaN   NaN   NaN   NaN
#
#      2015  Unnamed: 60
# 9     NaN          NaN
# 190   NaN          NaN
# 220   NaN          NaN
# 257   NaN          NaN
#
# [4 rows x 61 columns]

# %% [markdown]
# ## 数据质量的问题:
# 1. 有些行是多个国家的总和，而不是实际的国家(例如, "World").
# 2. 有些列是不相关的，可以被移除(例如, "Indicator Name").
# 3. 有些年份对于任何国家都没有数据(例如, 2015 到 2016).
# 4. 有些国家在任何年份都没有数据(例如, "American Samoa").

# %% [markdown]
# <br>

# %% [markdown]
# <h2> 1. 有些行是多个国家的总和，而不是实际的国家 (例如, "World"). </h2>
#
# **目标:**
# 移除不包含实际国家的行。幸运的是，世界银行(World Bank)提供了相应的元数据，表明了哪些行是国家，而哪些行是多个国家的总和。
# - 导入countries_metadata.csv
# - 在`Country Code`上将元数据与`data`合并

# %% [markdown]
# #### 获取 `countries_metadata.csv`

# %%
# !wget --output-document ./data/countries_metadata.csv https://ibm.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv
# Out:
# --2017-11-02 21:23:20--  https://ibm.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv
# 正在解析主机 ibm.box.com (ibm.box.com)... 107.152.24.197
# 正在连接 ibm.box.com (ibm.box.com)|107.152.24.197|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 301 Moved Permanently
# 位置：https://ibm.ent.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv [跟随至新的 URL]
# --2017-11-02 21:23:25--  https://ibm.ent.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv
# 正在解析主机 ibm.ent.box.com (ibm.ent.box.com)... 107.152.24.211
# 正在连接 ibm.ent.box.com (ibm.ent.box.com)|107.152.24.211|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 302 Found
# 位置：https://public.boxcloud.com/d/1/SrW-8oFbXJPcehrTqRslNPRXZxlF0Q6Ef3pH6YrsL79lr8YLVzjA7c_z_zUSoamqO4KkDBy-L1JpfWDCgRIZ2hI0YceVan4luXgHZ5pq_sICAuFdKknzaLupkQL5FDy6IL58xDyljTkn_KqZiJC94ZCoBt2xdnhqrAJH83udvc2Z3tEOG-iAoe4duuHk4rfISp1tFn1lRuW2-T1bFnUrLUYCpgq-WtWIX9XK6kbEYUWvro7p5ZHopV_f545nVvUwMCqdXNiqen_TBEVKsJwi9NinzBmjdV7feDkpteBP3T9G6CdHg8eLLwW6u
pM0TQF6z3Ef5RsG0NEeH6-smDuwwcacuby1DdPcPOYy_koBpFsmSEO8ymXtxZZvZV9OPjG6ygC3YE_RaPRflmiZ26Nb-Dlo6l8Rw40czbnM75b03CGOqn6L2etkjeV9CLm2l-M96S7p-tl89448dQl1hZkD6z2UYdVByqcHtLoP5A2RQmIRs3R_zm44Grqi0qkFmEZEywPqs9G_B6UWOAKff6DwxSshhNjlLdsGqjcgb-QuiRcCTyJ_0PUt0d_WrVv2CpjdncqS5_JNJhNYRK5NKGbserMMLsdjeknB1EcmuJ8QjSV7ii0YZGYZLHCUnSZ9aj66Y7L4IxzKzP2VcVEZcYYANzioJHQFbFjng_z8hoVWpMpkVVNNkl0i2WECrK0ZsFuH8UMAjQAehpAojm_Yy9gHWYrczcQvn6gj3-d-xD4y2V5-OhNwoD2fJzOXVZoPct5Db4jqnySYm8Jvp2sM315BXk3PcmGbff6akM15Dt2vTcGiKkQfuiXKdtqtwhyENdjdO10NOV6KF3i6y72YgO_2Pt4G5ZmDozMklVyRTD3XmAIi29sq9djDB2z7Jv-VTAcgUQwnu4WpefdpEQZN-9lqFi80oD1lJL3J1jBJpUkIBaQv9-joweREjK7snrgjlr8tmCu11PRh32zk_I8BB4jpdYAetUdbyzdlI6ZX/download
# 正在解析主机 public.boxcloud.com (public.boxcloud.com)... 107.152.25.200, 107.152.24.200
# 正在连接 public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度： 45978 (45K) [text/csv]
# 正在保存至: “./data/countries_metadata.csv”
#
# ./data/countries_me 100%[===================>]  44.90K  40.5KB/s    in 1.1s
#
# 2017-11-02 21:23:36 (40.5 KB/s) - 已保存 “./data/countries_metadata.csv” [45978/45978])

# %% [markdown]
# #### 导入 `countries_metadata.csv`

# %%
metadata = pd.read_csv("./data/countries_metadata.csv", encoding = "utf-8")

# %%
metadata.head(10)
# Out:
#         ﻿"Country Name" Country Code                      Region  \
# 0                 Aruba          ABW   Latin America & Caribbean
# 1           Afghanistan          AFG                  South Asia
# 2                Angola          AGO          Sub-Saharan Africa
# 3               Albania          ALB       Europe & Central Asia
# 4               Andorra          AND       Europe & Central Asia
# 5            Arab World          ARB                         NaN
# 6  United Arab Emirates          ARE  Middle East & North Africa
# 7             Argentina          ARG   Latin America & Caribbean
# 8               Armenia          ARM       Europe & Central Asia
# 9        American Samoa          ASM         East Asia & Pacific
#
#             IncomeGroup                                       SpecialNotes  \
# 0  High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1            Low income  Fiscal year end: March 20; reporting period fo...
# 2   Upper middle income  April 2013 database update: Based on IMF data,...
# 3   Upper middle income                                                NaN
# 4  High income: nonOECD                                                NaN
# 5                   NaN  Arab World aggregate. Arab World is composed o...
# 6  High income: nonOECD  April 2013 database update: Based on data from...
# 7  High income: nonOECD                 The base year has changed to 2004.
# 8   Lower middle income                                                NaN
# 9   Upper middle income                                                NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %% [markdown]
# #### 如何标识列出的"Country Name" 是一个国家还是一个多国构成的区域?

# %% [markdown]
# 注意，当某一行是像"Arab World"这样的聚合区域时,  `Region` 和 `IncomeGroup` 总是 NaN (Not a Number). 我们可以用这条规则来移除所有不是国家的区域.

# %% [markdown]
# #### 在关键字`Country Code`上合并`data` 与 `metadata`

# %%
merge = pd.merge(data, metadata, on = "Country Code")

# %%
merge.head(10)
# Out:
#            Country Name Country Code                          Indicator Name  \
# 0                 Aruba          ABW  CO2 emissions (metric tons per capita)
# 1           Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2                Angola          AGO  CO2 emissions (metric tons per capita)
# 3               Albania          ALB  CO2 emissions (metric tons per capita)
# 4               Andorra          AND  CO2 emissions (metric tons per capita)
# 5            Arab World          ARB  CO2 emissions (metric tons per capita)
# 6  United Arab Emirates          ARE  CO2 emissions (metric tons per capita)
# 7             Argentina          ARG  CO2 emissions (metric tons per capita)
# 8               Armenia          ARM  CO2 emissions (metric tons per capita)
# 9        American Samoa          ASM  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC  0.046060  0.053604  0.073765  0.074233  0.086292  0.101467
# 2  EN.ATM.CO2E.PC  0.097472  0.079038  0.201289  0.192535  0.201003  0.191528
# 3  EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742  1.166099
# 4  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 5  EN.ATM.CO2E.PC  0.643689  0.685151  0.760855  0.874941  0.999098  1.165705
# 6  EN.ATM.CO2E.PC  0.118758  0.108837  0.163018  0.175223  0.132355  0.146327
# 7  EN.ATM.CO2E.PC  2.367473  2.442616  2.522392  2.316356  2.538379  2.641714
# 8  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 9  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
#
#       ...           2013       2014  2015  2016  Unnamed: 61  \
# 0     ...       8.351294   8.408363   NaN   NaN          NaN
# 1     ...       0.315602   0.299445   NaN   NaN          NaN
# 2     ...       1.254617   1.291328   NaN   NaN          NaN
# 3     ...       1.749211   1.978763   NaN   NaN          NaN
# 4     ...       5.900753   5.832170   NaN   NaN          NaN
# 5     ...       4.650474   4.860234   NaN   NaN          NaN
# 6     ...      18.954164  23.302023   NaN   NaN          NaN
# 7     ...       4.462904   4.746797   NaN   NaN          NaN
# 8     ...       1.899712   1.902759   NaN   NaN          NaN
# 9     ...            NaN        NaN   NaN   NaN          NaN
#
#                        Region          IncomeGroup  \
# 0   Latin America & Caribbean          High income
# 1                  South Asia           Low income
# 2          Sub-Saharan Africa  Lower middle income
# 3       Europe & Central Asia  Upper middle income
# 4       Europe & Central Asia          High income
# 5                         NaN                  NaN
# 6  Middle East & North Africa          High income
# 7   Latin America & Caribbean  Upper middle income
# 8       Europe & Central Asia  Lower middle income
# 9         East Asia & Pacific  Upper middle income
#
#                                         SpecialNotes             TableName  \
# 0  SNA data for 2000-2011 are updated from offici...                 Aruba
# 1  Fiscal year end: March 20; reporting period fo...           Afghanistan
# 2                                                NaN                Angola
# 3                                                NaN               Albania
# 4  WB-3 code changed from ADO to AND to align wit...               Andorra
# 5  Arab World aggregate. Arab World is composed o...            Arab World
# 6                                                NaN  United Arab Emirates
# 7  National Institute of Statistics and Census re...             Argentina
# 8                                                NaN               Armenia
# 9                                                NaN        American Samoa
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
#
# [10 rows x 67 columns]

# %% [markdown]
# **注意:** 当某一行不是实际的国家时，'Region'的值就是 NaN.

# %% [markdown]
# #### 移除 `Region` 为 NaN 的行

# %%
merge = merge[pd.notnull(merge['Region'])]

# %%
merge.head(10)
# Out:
#             Country Name Country Code                          Indicator Name  \
# 0                  Aruba          ABW  CO2 emissions (metric tons per capita)
# 1            Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2                 Angola          AGO  CO2 emissions (metric tons per capita)
# 3                Albania          ALB  CO2 emissions (metric tons per capita)
# 4                Andorra          AND  CO2 emissions (metric tons per capita)
# 6   United Arab Emirates          ARE  CO2 emissions (metric tons per capita)
# 7              Argentina          ARG  CO2 emissions (metric tons per capita)
# 8                Armenia          ARM  CO2 emissions (metric tons per capita)
# 9         American Samoa          ASM  CO2 emissions (metric tons per capita)
# 10   Antigua and Barbuda          ATG  CO2 emissions (metric tons per capita)
#
#     Indicator Code      1960      1961      1962      1963      1964  \
# 0   EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN
# 1   EN.ATM.CO2E.PC  0.046060  0.053604  0.073765  0.074233  0.086292
# 2   EN.ATM.CO2E.PC  0.097472  0.079038  0.201289  0.192535  0.201003
# 3   EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742
# 4   EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN
# 6   EN.ATM.CO2E.PC  0.118758  0.108837  0.163018  0.175223  0.132355
# 7   EN.ATM.CO2E.PC  2.367473  2.442616  2.522392  2.316356  2.538379
# 8   EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN
# 9   EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN
# 10  EN.ATM.CO2E.PC  0.662643  0.849084  1.796794  1.446821  1.540135
#
#         1965     ...           2013       2014  2015  2016  Unnamed: 61  \
# 0        NaN     ...       8.351294   8.408363   NaN   NaN          NaN
# 1   0.101467     ...       0.315602   0.299445   NaN   NaN          NaN
# 2   0.191528     ...       1.254617   1.291328   NaN   NaN          NaN
# 3   1.166099     ...       1.749211   1.978763   NaN   NaN          NaN
# 4        NaN     ...       5.900753   5.832170   NaN   NaN          NaN
# 6   0.146327     ...      18.954164  23.302023   NaN   NaN          NaN
# 7   2.641714     ...       4.462904   4.746797   NaN   NaN          NaN
# 8        NaN     ...       1.899712   1.902759   NaN   NaN          NaN
# 9        NaN     ...            NaN        NaN   NaN   NaN          NaN
# 10  2.473585     ...       5.360453   5.377649   NaN   NaN          NaN
#
#                         Region          IncomeGroup  \
# 0    Latin America & Caribbean          High income
# 1                   South Asia           Low income
# 2           Sub-Saharan Africa  Lower middle income
# 3        Europe & Central Asia  Upper middle income
# 4        Europe & Central Asia          High income
# 6   Middle East & North Africa          High income
# 7    Latin America & Caribbean  Upper middle income
# 8        Europe & Central Asia  Lower middle income
# 9          East Asia & Pacific  Upper middle income
# 10   Latin America & Caribbean          High income
#
#                                          SpecialNotes             TableName  \
# 0   SNA data for 2000-2011 are updated from offici...                 Aruba
# 1   Fiscal year end: March 20; reporting period fo...           Afghanistan
# 2                                                 NaN                Angola
# 3                                                 NaN               Albania
# 4   WB-3 code changed from ADO to AND to align wit...               Andorra
# 6                                                 NaN  United Arab Emirates
# 7   National Institute of Statistics and Census re...             Argentina
# 8                                                 NaN               Armenia
# 9                                                 NaN        American Samoa
# 10                                                NaN   Antigua and Barbuda
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
#
# [10 rows x 67 columns]

# %% [markdown]
# <br>

# %% [markdown]
# <h2>2. 有些列是不相关的，可以被移除.</h2>

# %% [markdown]
# **目标:**
# 移除下列不相关的列:
# - 第 3 列: **"Indicator Name"**
# - 第 4 列: **"Indicator Code"**

# %%
merge.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', 'Unnamed: 61', 'Region', 'IncomeGroup',
#        'SpecialNotes', 'TableName', 'Unnamed: 5'],
#       dtype='object')

# %%
? merge.drop

# %%
merge = merge.drop(merge.columns[[61,66]], axis=1) # Note: zero indexed
merge = merge.drop('Indicator Name', axis=1)
merge = merge.drop('Indicator Code', 1)

# %%
merge.columns
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', 'Region',
#        'IncomeGroup', 'SpecialNotes', 'TableName'],
#       dtype='object')

# %% [markdown]
# <h2>3. 有些年份对于任何国家都没有数据.</h2>

# %% [markdown]
# **目标:**
# 计算每一年的数据行数，NaN值不计算在内.

# %%
merge.count()
# Out:
# Country Name    217
# Country Code    217
# 1960            151
# 1961            152
# 1962            154
# 1963            155
# 1964            161
# 1965            161
# 1966            161
# 1967            161
# 1968            161
# 1969            161
# 1970            163
# 1971            164
# 1972            166
# 1973            166
# 1974            166
# 1975            166
# 1976            166
# 1977            166
# 1978            166
# 1979            166
# 1980            166
# 1981            166
# 1982            166
# 1983            166
# 1984            166
# 1985            166
# 1986            167
# 1987            167
#                ...
# 1991            174
# 1992            195
# 1993            195
# 1994            196
# 1995            197
# 1996            197
# 1997            198
# 1998            199
# 1999            199
# 2000            199
# 2001            199
# 2002            200
# 2003            200
# 2004            200
# 2005            201
# 2006            202
# 2007            203
# 2008            203
# 2009            203
# 2010            203
# 2011            203
# 2012            205
# 2013            205
# 2014            203
# 2015              0
# 2016              0
# Region          217
# IncomeGroup     217
# SpecialNotes    104
# TableName       217
# dtype: int64

# %% [markdown]
# 查看2015年，看起来所有行都不包含2015年的数据.

# %%
merge['2015']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
#        ..
# 225   NaN
# 226   NaN
# 229   NaN
# 230   NaN
# 231   NaN
# 232   NaN
# 234   NaN
# 236   NaN
# 239   NaN
# 240   NaN
# 241   NaN
# 242   NaN
# 243   NaN
# 244   NaN
# 245   NaN
# 247   NaN
# 248   NaN
# 249   NaN
# 250   NaN
# 251   NaN
# 252   NaN
# 253   NaN
# 254   NaN
# 255   NaN
# 257   NaN
# 258   NaN
# 259   NaN
# 260   NaN
# 261   NaN
# 262   NaN
# Name: 2015, dtype: float64

# %% [markdown]
# #### 移除任何行都不包含数据的列

# %%
merge = merge.drop(['2015', '2016'], 1)

# %%
merge.count() #double-check that columns have been removed
# Out:
# Country Name    217
# Country Code    217
# 1960            151
# 1961            152
# 1962            154
# 1963            155
# 1964            161
# 1965            161
# 1966            161
# 1967            161
# 1968            161
# 1969            161
# 1970            163
# 1971            164
# 1972            166
# 1973            166
# 1974            166
# 1975            166
# 1976            166
# 1977            166
# 1978            166
# 1979            166
# 1980            166
# 1981            166
# 1982            166
# 1983            166
# 1984            166
# 1985            166
# 1986            167
# 1987            167
#                ...
# 1989            167
# 1990            173
# 1991            174
# 1992            195
# 1993            195
# 1994            196
# 1995            197
# 1996            197
# 1997            198
# 1998            199
# 1999            199
# 2000            199
# 2001            199
# 2002            200
# 2003            200
# 2004            200
# 2005            201
# 2006            202
# 2007            203
# 2008            203
# 2009            203
# 2010            203
# 2011            203
# 2012            205
# 2013            205
# 2014            203
# Region          217
# IncomeGroup     217
# SpecialNotes    104
# TableName       217
# dtype: int64

# %% [markdown]
# <h2>4. 有些国家在任何年份都没有数据.</h2>

# %% [markdown]
# **目标:**
# 使用行平均值来确定哪些国家不包含任何数据.

# %% [markdown]
# 计算每一行的平均值(在 axis 1 上).

# %%
merge.mean(axis=1) #Takes the mean of all numeric quantities by row
# Out:
# 0      20.486262
# 1       0.147484
# 2       0.600522
# 3       1.656215
# 4       6.888830
# 6      30.452819
# 7       3.633115
# 8       1.344459
# 9            NaN
# 10      4.824503
# 11     14.533135
# 12      7.198942
# 13      4.184062
# 14      0.030754
# 15     11.215788
# 16      0.209032
# 17      0.067407
# 18      0.194050
# 19      7.106923
# 20     20.284362
# 21     12.631206
# 22      3.971538
# 23      6.283099
# 24      1.345642
# 25      7.538987
# 26      0.945658
# 27      1.474204
# 28      3.231488
# 29     21.024915
# 30      0.390093
#          ...
# 225     4.328909
# 226     0.033163
# 229     0.212351
# 230     1.816982
# 231     0.453896
# 232     9.590787
# 234     0.220787
# 236     0.654379
# 239    16.614263
# 240     1.531793
# 241     2.423008
# 242     0.894346
# 243     0.119932
# 244     0.075384
# 245     7.206894
# 247     1.769533
# 248    19.134419
# 249     4.521001
# 250     0.938539
# 251     5.951815
# 252     3.803970
# 253          NaN
# 254     0.645479
# 255     0.515255
# 257     0.613257
# 258          NaN
# 259     0.719367
# 260     8.132758
# 261     0.484002
# 262     1.211731
# dtype: float64

# %% [markdown]
# 正如你所见，在不包含任何数据的行中出现了 NaN.

# %% [markdown]
# #### 移除所有年份中不包含任何数据的行

# %%
merge = merge[pd.notnull(merge.mean(axis=1))]

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align = "center">数据清洗 ... 完成!</h2>

# %% [markdown]
# ### 为了方便起见，重新命名

# %%
mydf = merge
mydf
# Out:
#                        Country Name Country Code       1960       1961  \
# 0                             Aruba          ABW        NaN        NaN
# 1                       Afghanistan          AFG   0.046060   0.053604
# 2                            Angola          AGO   0.097472   0.079038
# 3                           Albania          ALB   1.258195   1.374186
# 4                           Andorra          AND        NaN        NaN
# 6              United Arab Emirates          ARE   0.118758   0.108837
# 7                         Argentina          ARG   2.367473   2.442616
# 8                           Armenia          ARM        NaN        NaN
# 10              Antigua and Barbuda          ATG   0.662643   0.849084
# 11                        Australia          AUS   8.582937   8.641569
# 12                          Austria          AUT   4.373319   4.496362
# 13                       Azerbaijan          AZE        NaN        NaN
# 14                          Burundi          BDI        NaN        NaN
# 15                          Belgium          BEL   9.941594  10.103872
# 16                            Benin          BEN   0.066354   0.052049
# 17                     Burkina Faso          BFA   0.009112   0.018730
# 18                       Bangladesh          BGD        NaN        NaN
# 19                         Bulgaria          BGR   2.833901   3.269920
# 20                          Bahrain          BHR   3.544478  10.549281
# 21                     Bahamas, The          BHS   3.749763   4.746699
# 22           Bosnia and Herzegovina          BIH        NaN        NaN
# 23                          Belarus          BLR        NaN        NaN
# 24                           Belize          BLZ   0.477972   0.387211
# 25                          Bermuda          BMU   3.551374   3.868484
# 26                          Bolivia          BOL   0.272038   0.276621
# 27                           Brazil          BRA   0.649631   0.661771
# 28                         Barbados          BRB   0.746297   0.838884
# 29                Brunei Darussalam          BRN   4.082170   3.555785
# 30                           Bhutan          BTN        NaN        NaN
# 31                         Botswana          BWA        NaN        NaN
# ..                              ...          ...        ...        ...
# 223                      Seychelles          SYC        NaN        NaN
# 224            Syrian Arab Republic          SYR   0.704774   0.649233
# 225        Turks and Caicos Islands          TCA        NaN        NaN
# 226                            Chad          TCD   0.018325   0.016775
# 229                            Togo          TGO   0.041762   0.057386
# 230                        Thailand          THA   0.135586   0.146944
# 231                      Tajikistan          TJK        NaN        NaN
# 232                    Turkmenistan          TKM        NaN        NaN
# 234                     Timor-Leste          TLS        NaN        NaN
# 236                           Tonga          TON   0.178585   0.172578
# 239             Trinidad and Tobago          TTO   3.042583   5.318116
# 240                         Tunisia          TUN   0.413565   0.417262
# 241                          Turkey          TUR   0.612272   0.616880
# 242                          Tuvalu          TUV        NaN        NaN
# 243                        Tanzania          TZA   0.082261   0.067872
# 244                          Uganda          UGA   0.062123   0.058093
# 245                         Ukraine          UKR        NaN        NaN
# 247                         Uruguay          URY   1.701583   1.602724
# 248                   United States          USA  15.999779  15.681256
# 249                      Uzbekistan          UZB        NaN        NaN
# 250  St. Vincent and the Grenadines          VCT   0.135900   0.133927
# 251                   Venezuela, RB          VEN   7.005105   6.136885
# 252          British Virgin Islands          VGB        NaN        NaN
# 254                         Vietnam          VNM   0.215631   0.225435
# 255                         Vanuatu          VUT        NaN        NaN
# 257                           Samoa          WSM   0.135007   0.163532
# 259                     Yemen, Rep.          YEM   0.702611   0.506779
# 260                    South Africa          ZAF   5.629599   5.726258
# 261                          Zambia          ZMB        NaN        NaN
# 262                        Zimbabwe          ZWE        NaN        NaN
#
#           1962       1963       1964       1965       1966       1967  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1     0.073765   0.074233   0.086292   0.101467   0.107637   0.123734
# 2     0.201289   0.192535   0.201003   0.191528   0.246413   0.154912
# 3     1.439956   1.181681   1.111742   1.166099   1.333055   1.363746
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# 6     0.163018   0.175223   0.132355   0.146327   0.159950   5.383685
# 7     2.522392   2.316356   2.538379   2.641714   2.792654   2.858162
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 10    1.796794   1.446821   1.540135   2.473585   5.613448   8.912847
# 11    8.835688   9.226440   9.759073  10.622321  10.328092  10.955625
# 12    4.755362   5.155194   5.391004   5.252197   5.361725   5.417737
# 13         NaN        NaN        NaN        NaN        NaN        NaN
# 14    0.015207   0.016160   0.015833   0.011914   0.015121   0.014740
# 15   10.641190  11.386929  11.053655  11.141656  11.042019  11.217257
# 16    0.054209   0.047589   0.055304   0.057115   0.042383   0.052284
# 17    0.017003   0.017504   0.021575   0.019841   0.019534   0.019217
# 18         NaN        NaN        NaN        NaN        NaN        NaN
# 19    3.835892   4.259781   5.262988   5.645652   5.905437   6.638369
# 20    9.191644   6.710688   8.742076   6.554119   3.384394   5.124669
# 21    5.996432   5.558111   8.118536   9.399610   7.465983  11.173358
# 22         NaN        NaN        NaN        NaN        NaN        NaN
# 23         NaN        NaN        NaN        NaN        NaN        NaN
#
# 14            Low income                                                NaN
# 15           High income  A simple multiplier is used to convert the nat...
# 16            Low income                                                NaN
# 17            Low income                                                NaN
# 18   Lower middle income  Fiscal year end: June 30; reporting period for...
# 19   Upper middle income  The new reference year for chain linked series...
# 20           High income                                                NaN
# 21           High income                                                NaN
# 22   Upper middle income                                                NaN
# 23   Upper middle income  In July 2016 a new Belarusian ruble was introd...
# 24   Upper middle income                                                NaN
# 25           High income                                                NaN
# 26   Lower middle income                                                NaN
# 27   Upper middle income                                                NaN
# 28           High income                                                NaN
# 29           High income  National accounts revision is based on data fr...
# 30   Lower middle income                                                NaN
# 31   Upper middle income  Fiscal year end: March 31; reporting period fo...
# ..                   ...                                                ...
# 223          High income                                                NaN
# 224  Lower middle income                                                NaN
# 225          High income                                                NaN
# 226           Low income                                                NaN
# 229           Low income                                                NaN
# 230  Upper middle income  Fiscal year end: September 30; reporting perio...
# 231  Lower middle income                                                NaN
# 232  Upper middle income                                                NaN
# 234  Lower middle income  WB-3 code changed from TMP to TLS to align wit...
# 236  Upper middle income                                                NaN
# 239          High income                                                NaN
# 240  Lower middle income                                                NaN
# 241  Upper middle income                                                NaN
# 242  Upper middle income  Value added is measured at producer prices up ...
# 243           Low income  Tanzania reports using a blend of SNA 1993 and...
# 244           Low income  Fiscal year end: June 30; reporting period for...
# 245  Lower middle income                         The new base year is 2010.
# 247          High income                                                NaN
# 248          High income  Fiscal year end: September 30; reporting perio...
# 249  Lower middle income                                                NaN
# 250  Upper middle income                                                NaN
# 251  Upper middle income                                                NaN
# 252          High income                                                NaN
# 254  Lower middle income                                                NaN
# 255  Lower middle income  Based on official government statistics, value...
# 257  Upper middle income  Fiscal year ends on June 30; reporting period ...
# 259  Lower middle income  Based on official government statistics and In...
# 260  Upper middle income  Fiscal year end: March 31; reporting period fo...
# 261  Lower middle income  The base year is 2010. National accounts data ...
# 262           Low income  Fiscal year end: June 30; reporting period for...
#
#                           TableName
# 0                             Aruba
# 1                       Afghanistan
# 2                            Angola
# 3                           Albania
# 4                           Andorra
# 6              United Arab Emirates
# 7                         Argentina
# 8                           Armenia
# 10              Antigua and Barbuda
# 11                        Australia
# 12                          Austria
# 13                       Azerbaijan
# 14                          Burundi
# 15                          Belgium
# 16                            Benin
# 17                     Burkina Faso
# 18                       Bangladesh
# 19                         Bulgaria
# 20                          Bahrain
# 21                     Bahamas, The
# 22           Bosnia and Herzegovina
# 23                          Belarus
# 24                           Belize
# 25                          Bermuda
# 26                          Bolivia
# 27                           Brazil
# 28                         Barbados
# 29                Brunei Darussalam
# 30                           Bhutan
# 31                         Botswana
# ..                              ...
# 223                      Seychelles
# 224            Syrian Arab Republic
# 225        Turks and Caicos Islands
# 226                            Chad
# 229                            Togo
# 230                        Thailand
# 231                      Tajikistan
# 232                    Turkmenistan
# 234                     Timor-Leste
# 236                           Tonga
# 239             Trinidad and Tobago
# 240                         Tunisia
# 241                          Turkey
# 242                          Tuvalu
# 243                        Tanzania
# 244                          Uganda
# 245                         Ukraine
# 247                         Uruguay
# 248                   United States
# 249                      Uzbekistan
# 250  St. Vincent and the Grenadines
# 251                   Venezuela, RB
# 252          British Virgin Islands
# 254                         Vietnam
# 255                         Vanuatu
# 257                           Samoa
# 259                     Yemen, Rep.
# 260                    South Africa
# 261                          Zambia
# 262                        Zimbabwe
#
# [206 rows x 61 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# 代码汇总:

# %%
import pandas as pd

#Download data
#!wget --output-document co2emissions.csv https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv
#!wget --output-document countries_metadata.csv https://ibm.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv
    
#Import data
data = pd.read_csv("resources/data/co2emissions.csv", skiprows = 4)
metadata = pd.read_csv("resources/data/countries_metadata.csv", encoding = "utf-8")

#Merge data
merge = pd.merge(data, metadata, on = "Country Code")

#Remove non-country regions
merge = merge[pd.notnull(merge['Region'])]

#Drop some columns with no data
merge = merge.drop(merge.columns[[61,66]], axis=1)
merge = merge.drop(['Indicator Name', 'Indicator Code','2015', '2016'], 1)

#Drop some rows with no data
merge = merge[pd.notnull(merge.mean(axis=1))]

#Rename
mydf = merge

# %%
mydf
# Out:
#                        Country Name Country Code       1960       1961  \
# 0                             Aruba          ABW        NaN        NaN
# 1                       Afghanistan          AFG   0.046060   0.053604
# 2                            Angola          AGO   0.097472   0.079038
# 3                           Albania          ALB   1.258195   1.374186
# 4                           Andorra          AND        NaN        NaN
# 6              United Arab Emirates          ARE   0.118758   0.108837
# 7                         Argentina          ARG   2.367473   2.442616
# 8                           Armenia          ARM        NaN        NaN
# 10              Antigua and Barbuda          ATG   0.662643   0.849084
# 11                        Australia          AUS   8.582937   8.641569
# 12                          Austria          AUT   4.373319   4.496362
# 13                       Azerbaijan          AZE        NaN        NaN
# 14                          Burundi          BDI        NaN        NaN
# 15                          Belgium          BEL   9.941594  10.103872
# 16                            Benin          BEN   0.066354   0.052049
# 17                     Burkina Faso          BFA   0.009112   0.018730
# 18                       Bangladesh          BGD        NaN        NaN
# 19                         Bulgaria          BGR   2.833901   3.269920
# 20                          Bahrain          BHR   3.544478  10.549281
# 21                     Bahamas, The          BHS   3.749763   4.746699
# 22           Bosnia and Herzegovina          BIH        NaN        NaN
# 23                          Belarus          BLR        NaN        NaN
# 24                           Belize          BLZ   0.477972   0.387211
# 25                          Bermuda          BMU   3.551374   3.868484
# 26                          Bolivia          BOL   0.272038   0.276621
# 27                           Brazil          BRA   0.649631   0.661771
# 28                         Barbados          BRB   0.746297   0.838884
# 29                Brunei Darussalam          BRN   4.082170   3.555785
# 30                           Bhutan          BTN        NaN        NaN
# 31                         Botswana          BWA        NaN        NaN
# ..                              ...          ...        ...        ...
# 223                      Seychelles          SYC        NaN        NaN
# 224            Syrian Arab Republic          SYR   0.704774   0.649233
# 225        Turks and Caicos Islands          TCA        NaN        NaN
# 226                            Chad          TCD   0.018325   0.016775
# 229                            Togo          TGO   0.041762   0.057386
# 230                        Thailand          THA   0.135586   0.146944
# 231                      Tajikistan          TJK        NaN        NaN
# 232                    Turkmenistan          TKM        NaN        NaN
# 234                     Timor-Leste          TLS        NaN        NaN
# 236                           Tonga          TON   0.178585   0.172578
# 226   0.048200   0.053329   0.053778          Sub-Saharan Africa
# 229   0.362451   0.377480   0.362697          Sub-Saharan Africa
# 230   4.371765   4.403808   4.621860         East Asia & Pacific
# 231   0.366926   0.425540   0.620467       Europe & Central Asia
# 232  12.314897  12.436133  12.517295       Europe & Central Asia
# 234   0.253605   0.371541   0.387014         East Asia & Pacific
# 236   1.013263   1.079267   1.143966         East Asia & Pacific
# 239  33.855000  34.520032  34.163243   Latin America & Caribbean
# 240   2.480446   2.511904   2.587060  Middle East & North Africa
# 241   4.419488   4.285301   4.491479       Europe & Central Asia
# 242   1.025734   1.016822   1.008526         East Asia & Pacific
# 243   0.194471   0.220730   0.221347          Sub-Saharan Africa
# 244   0.112110   0.129675   0.134656          Sub-Saharan Africa
# 245   6.487603   5.976642   5.020747       Europe & Central Asia
# 247   2.559620   2.226236   1.973151   Latin America & Caribbean
# 248  16.304022  16.315879  16.493666               North America
# 249   3.889733   3.417442   3.420723       Europe & Central Asia
# 250   2.314348   1.911992   1.911345   Latin America & Caribbean
# 251   6.649233   6.066461   6.025698   Latin America & Caribbean
# 252   6.174050   6.057819   6.072834   Latin America & Caribbean
# 254   1.601421   1.640273   1.839666         East Asia & Pacific
# 255   0.459329   0.420092   0.594993         East Asia & Pacific
# 257   1.046640   1.038064   1.029788         East Asia & Pacific
# 259   0.749447   0.996885   0.864835  Middle East & North Africa
# 260   8.927862   8.748064   9.045270          Sub-Saharan Africa
# 261   0.249457   0.261113   0.288271          Sub-Saharan Africa
# 262   0.529703   0.775564   0.779956          Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes  \
# 0            High income  SNA data for 2000-2011 are updated from offici...
# 1             Low income  Fiscal year end: March 20; reporting period fo...
# 2    Lower middle income                                                NaN
# 3    Upper middle income                                                NaN
# 4            High income  WB-3 code changed from ADO to AND to align wit...
# 6            High income                                                NaN
# 7    Upper middle income  National Institute of Statistics and Census re...
# 8    Lower middle income                                                NaN
# 10           High income                                                NaN
# 11           High income  Fiscal year end: June 30; reporting period for...
# 12           High income  A simple multiplier is used to convert the nat...
# 13   Upper middle income                                                NaN
# 14            Low income                                                NaN
# 15           High income  A simple multiplier is used to convert the nat...
# 16            Low income                                                NaN
# 17            Low income                                                NaN
# 18   Lower middle income  Fiscal year end: June 30; reporting period for...
# 19   Upper middle income  The new reference year for chain linked series...
# 20           High income                                                NaN
# 21           High income                                                NaN
# 22   Upper middle income                                                NaN
# 23   Upper middle income  In July 2016 a new Belarusian ruble was introd...
# 24   Upper middle income                                                NaN
# 25           High income                                                NaN
# 26   Lower middle income                                                NaN
# 27   Upper middle income                                                NaN
# 28           High income                                                NaN
# 29           High income  National accounts revision is based on data fr...
# 30   Lower middle income                                                NaN
# 31   Upper middle income  Fiscal year end: March 31; reporting period fo...
# ..                   ...                                                ...
# 223          High income                                                NaN
# 224  Lower middle income                                                NaN
# 225          High income                                                NaN
# 226           Low income                                                NaN
# 229           Low income                                                NaN
# 230  Upper middle income  Fiscal year end: September 30; reporting perio...
# 231  Lower middle income                                                NaN
# 232  Upper middle income                                                NaN
# 234  Lower middle income  WB-3 code changed from TMP to TLS to align wit...
# 236  Upper middle income                                                NaN
# 239          High income                                                NaN
# 240  Lower middle income                                                NaN
# 241  Upper middle income                                                NaN
# 242  Upper middle income  Value added is measured at producer prices up ...
# 243           Low income  Tanzania reports using a blend of SNA 1993 and...
# 244           Low income  Fiscal year end: June 30; reporting period for...
# 245  Lower middle income                         The new base year is 2010.
# 247          High income                                                NaN
# 248          High income  Fiscal year end: September 30; reporting perio...
# 249  Lower middle income                                                NaN
# 250  Upper middle income                                                NaN
# 251  Upper middle income                                                NaN
# 252          High income                                                NaN
# 254  Lower middle income                                                NaN
# 255  Lower middle income  Based on official government statistics, value...
# 257  Upper middle income  Fiscal year ends on June 30; reporting period ...
# 259  Lower middle income  Based on official government statistics and In...
# 260  Upper middle income  Fiscal year end: March 31; reporting period fo...
# 261  Lower middle income  The base year is 2010. National accounts data ...
# 262           Low income  Fiscal year end: June 30; reporting period for...
#
#                           TableName
# 0                             Aruba
# 1                       Afghanistan
# 2                            Angola
# 3                           Albania
# 4                           Andorra
# 6              United Arab Emirates
# 7                         Argentina
# 8                           Armenia
# 10              Antigua and Barbuda
# 11                        Australia
# 12                          Austria
# 13                       Azerbaijan
# 14                          Burundi
# 15                          Belgium
# 16                            Benin
# 17                     Burkina Faso
# 18                       Bangladesh
# 19                         Bulgaria
# 20                          Bahrain
# 21                     Bahamas, The
# 22           Bosnia and Herzegovina
# 23                          Belarus
# 24                           Belize
# 25                          Bermuda
# 26                          Bolivia
# 27                           Brazil
# 28                         Barbados
# 29                Brunei Darussalam
# 30                           Bhutan
# 31                         Botswana
# ..                              ...
# 223                      Seychelles
# 224            Syrian Arab Republic
# 225        Turks and Caicos Islands
# 226                            Chad
# 229                            Togo
# 230                        Thailand
# 231                      Tajikistan
# 232                    Turkmenistan
# 234                     Timor-Leste
# 236                           Tonga
# 239             Trinidad and Tobago
# 240                         Tunisia
# 241                          Turkey
# 242                          Tuvalu
# 243                        Tanzania
# 244                          Uganda
# 245                         Ukraine
# 247                         Uruguay
# 248                   United States
# 249                      Uzbekistan
# 250  St. Vincent and the Grenadines
# 251                   Venezuela, RB
# 252          British Virgin Islands
# 254                         Vietnam
# 255                         Vanuatu
# 257                           Samoa
# 259                     Yemen, Rep.
# 260                    South Africa
# 261                          Zambia
# 262                        Zimbabwe
#
# [206 rows x 61 columns]

# %% [markdown]
# 想要导出为 csv 文件?

# %%
mydf.to_csv("resources/data/co2emissions_cleaned.csv", index = False) #See Recent Data for exported csv

# %% [markdown]
# <hr></hr>
# <div class="alert alert-success alertsuccess" style="margin-top: 0px">
# <h4> [tip] 数据清洗的规则来源于对业务的理解 </h4>
# <p></p>
# 从上面的清洗过程我们可以看到，无论是如何区分国家和地区，还是剔除不包含数据的国家，都需要明确的清洗规则，而清洗规则是依靠我们对业务的理解而确定的，单纯从数据本身出发，是无法制定出这样的规则的。
# <li>这再次说明，数据分析是业务驱动的，并且需要业务模型的支持。</li>
# <li>计算机能够帮助我们的，是依靠强大的计算能力来加速数据分析的过程。</li>
# <p></p>
# </div>
# <hr></hr>
